# %% [markdown]
# <a href="https://colab.research.google.com/github/sagnikmitra/ML_colab/blob/master/Distributed_Computin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dask['complete']
# Out:
# ...
#      |████████████████████████████████| 624kB 2.8MB/s
# ...
#      |████████████████████████████████| 501kB 48.0MB/s
# ...
#   Created wheel for tornado: filename=tornado-6.0.4-cp36-cp36m-linux_x86_64.whl size=427637 sha256=4774b3f4b9f1a2ef1f5ac3b3a7ddac77ccde8659e9dce8b94e14359877992393
#   Stored in directory: /root/.cache/pip/wheels/93/84/2f/409c7b2bb3afc3aa727f7ee8787975e0793f74d1165f4d0104
# ...
#   Created wheel for locket: filename=locket-0.2.0-cp36-none-any.whl size=4040 sha256=c0e440d50fc74b37ce76fcdd7e4f664dc8b2654b7674d10c0a018930641a2566
#   Stored in directory: /root/.cache/pip/wheels/26/1e/e8/4fa236ec931b1a0cdd61578e20d4934d7bf188858723b84698
# Successfully built tornado locket
# ...
#   Found existing installation: tornado 4.5.3
#     Uninstalling tornado-4.5.3:
#       Successfully uninstalled tornado-4.5.3
#   Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
# ...

# %%
print('SAGNIK'.lower())
# Out:
# sagnik

# %%
import numpy as np
import dask.array as da

# %%
np_arr = np.random.randint(20,size=21)

# %%
np_arr
# Out:
# array([15, 13,  3, 13, 18, 17,  4, 11, 10, 13, 15,  7,  8,  1, 10, 10,  8,
#         3,  1, 14, 11])

# %%
dask_arr = da.random.randint(20,size=24, chunks=3)
dask_arr
# Out:
# dask.array<randint, shape=(24,), dtype=int64, chunksize=(3,), chunktype=numpy.ndarray>

# %%
dask_arr = da.random.randint(20,size=26, chunks=3)
dask_arr
# Out:
# dask.array<randint, shape=(26,), dtype=int64, chunksize=(3,), chunktype=numpy.ndarray>

# %%
dask_arr_from_np = da.from_array([12,17,19,31,25,2,78,74,99,18,78,89,75,23],chunks=9)

# %%
dask_arr_from_np
# Out:
# dask.array<array, shape=(14,), dtype=int64, chunksize=(9,), chunktype=numpy.ndarray>

# %% [markdown]
# Let's Try to visualize the Entire Thing in form of Algo

# %%
dask_arr_from_np.sum().visualize()

# %%
dask_arr_from_np.sum()
# Out:
# dask.array<sum-aggregate, shape=(), dtype=int64, chunksize=(), chunktype=numpy.ndarray>

# %%
1024*1024*1024
# Out:
# 1073741824

# %%
x = da.random.random(10, chunks=2)
y = da.random.random(10, chunks=2)
sum_x_y = da.add(x,y) #similar to numpy.add()
mean_x_y = da.mean(sum_x_y)

# %%
sum_x_y = da.add(x,y)

# %%
sum_x_y
# Out:
# dask.array<add, shape=(10,), dtype=float64, chunksize=(2,), chunktype=numpy.ndarray>

# %%
mean_x_y
# Out:
# dask.array<mean_agg-aggregate, shape=(), dtype=float64, chunksize=(), chunktype=numpy.ndarray>

# %%
sum_x_y.visualize()

# %%
mean_x_y.visualize()

# %%
da_arr_large = da.random.randint(10000,size = (50000,50000), chunks = (5000,1000))
da_sum_large = da_arr_large.sum()

# %%
da_sum_large
# Out:
# dask.array<sum-aggregate, shape=(), dtype=int64, chunksize=(), chunktype=numpy.ndarray>

# %%
da_arr_large.nbytes
# Out:
# 20000000000

# %%
np_arr_large = np.random.random(10000,size = (50000,50000), chunks = (5000,1000))
np_sum_large = np_arr_large.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-a1e44bcd8943> in <module>()
# ----> 1 np_arr_large = np.random.random(10000,size = (50000,50000), chunks = (5000,1000))
#       2 np_sum_large = np_arr_large.sum()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.random()
#
# TypeError: random() got multiple values for keyword argument 'size'
